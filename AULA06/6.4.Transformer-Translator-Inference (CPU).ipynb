# %% [markdown]
# # Dependencias

# %%
# !pip install "tensorflow-text>=2.11"
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
# ...

# %%
import numpy as np
import tensorflow as tf
import tensorflow_text as tf_text

# %% [markdown]
# # Carregar Modelo

# %%
# !rm -rf ./translator
# !gdown 1z3Yztbj46IGauTmXQVxLZYGVUhnFtWDT
# !unzip transformer-translator.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1z3Yztbj46IGauTmXQVxLZYGVUhnFtWDT
# To: /content/transformer-translator.zip
# 100% 116M/116M [00:02<00:00, 45.4MB/s]
# Archive:  transformer-translator.zip
#    creating: translator/
#    creating: translator/assets/
#   inflating: translator/assets/en_vocab.txt
#   inflating: translator/assets/pt_vocab.txt
#   inflating: translator/saved_model.pb
#  extracting: translator/fingerprint.pb
#    creating: translator/variables/
#   inflating: translator/variables/variables.data-00000-of-00001
#   inflating: translator/variables/variables.index

# %%
saved_model = tf.saved_model.load('translator')

# %% [markdown]
# # Teste

# %%
# %%time
inputs = [
    'Faz muito frio aqui.',
    'Esta é minha vida.',
    'Seu quarto é um desastre.',
    'Ainda está em casa?',
    'Tem certeza?'
]

for t in inputs:
  print(saved_model(t).numpy().decode())

print()
# Out:
# it makes it very cold here .
# this is my life .
# his fourth is a disaster .
# are you still at home ?
# are you sure ?
#
# CPU times: user 3.95 s, sys: 121 ms, total: 4.07 s
# Wall time: 4.13 s

# %%
input = 'Faz muito frio aqui. Esta é minha vida. Seu quarto é um desastre. Ainda está em casa? Tem certeza?'

print(saved_model(input).numpy().decode())

print()
# Out:
# it does it make a lot cold here . that ' s my life , and it ' s a disaster — is it still at home ? you ' re sure ?
